# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"D:\python eda\diabetes_prediction_dataset.csv")
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
# ...

# %%
sns.boxplot(x='diabetes', y='age', data=df)
plt.title('Age vs Diabetes')
plt.show()

# %%
sns.histplot(df['age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %%
print("Numeric columns:", numeric_cols)
# Out:
# Numeric columns: ['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv(r"D:\python eda\diabetes_prediction_dataset.csv")

# 1. Countplot: Gender vs Diabetes
sns.countplot(x='gender', hue='diabetes', data=df)
plt.title('Gender vs Diabetes Count')
plt.show()

# 2. Boxplot: BMI vs Diabetes
sns.boxplot(x='diabetes', y='bmi', data=df)
plt.title('BMI vs Diabetes')
plt.show()

# 3. Histogram: Glucose Level Distribution
sns.histplot(df['blood_glucose_level'], kde=True)
plt.title('Blood Glucose Level Distribution')
plt.show()

# 4. Violin Plot: Age vs Diabetes
sns.violinplot(x='diabetes', y='age', data=df)
plt.title('Age vs Diabetes (Violin Plot)')
plt.show()

# 5. Bar Chart: Smoking Status vs Diabetes
sns.countplot(x='smoking_history', hue='diabetes', data=df)
plt.title('Smoking History vs Diabetes')
plt.xticks(rotation=45)
plt.show()

#6. pairplot
df_sample = df.sample(500)  # randomly select 500 rows
sns.pairplot(df_sample[selected_cols], hue='diabetes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 37
#      35 numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
#      36 if len(numeric_cols) <= 10:
# ---> 37     sns.pairplot(df[numeric_cols + ['diabetes']], hue='diabetes')
#      38     plt.show()
#      39 else:
#
# File d:\python eda\myvenv\Lib\site-packages\seaborn\axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
# ...

# %%
print(df['diabetes'].unique())
print(df['diabetes'].dtype)
# Out:
# [0 1]
# int64

# %%
# Manually pick 3-4 useful numeric columns for pairplot
selected_cols = ['age', 'bmi', 'blood_glucose_level', 'diabetes']  # Change names if needed

# Check if all selected columns exist in the dataset
for col in selected_cols:
    if col not in df.columns:
        print(f"Column '{col}' not found in dataset!")
        
# If all columns exist, make pairplot
if all(col in df.columns for col in selected_cols):
    sns.pairplot(df[selected_cols], hue='diabetes')
    plt.show()
else:
    print("Pairplot skipped due to missing columns.")

# %%
df_sample = df.sample(500)  # randomly select 500 rows
sns.pairplot(df_sample[selected_cols], hue='diabetes')
plt.show()
